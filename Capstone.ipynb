# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# ### This notebook will contain the code for completing the capstone project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get the Covid-19 daily results from the web

# %%
#Load Data
import requests

url = 'https://www.worldometers.info/coronavirus/usa/florida/'   #table containing counts by caounty

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}                                          # set headers for compatability
r = requests.get(url, headers=header)      # make the get request
df = pd.read_html(r.text)                  # get the tables
df_fla = df[0]                             # keep only the case data
df_fla                                     # show the table
# Out:
#            County  TotalCases NewCases  TotalDeaths  NewDeaths  ActiveCases  \
# 0   Florida Total      389868  +10,249       5520.0      173.0     344397.0
# 1      Miami-Dade       95068   +2,723       1354.0       12.0      93714.0
# 2         Broward       45010   +1,263        536.0        7.0      44474.0
# 3      Palm Beach       28267     +761        727.0       18.0      27540.0
# 4    Hillsborough       25432     +541        278.0       18.0      25154.0
# ..            ...         ...      ...          ...        ...          ...
# 65      Jefferson         156      +34          5.0        NaN        151.0
# 66       Franklin          82       +1          1.0        NaN         81.0
# 67      Lafayette          75       +1          NaN        NaN         75.0
# 68     Unassigned         597      +35          NaN        NaN          NaN
# 69         Total:      389868  +10,249       5520.0      173.0     344397.0
#
#     TotalTests             Source
# 0      3215185                NaN
# 1       535356  [county]* [state]
# 2       343039  [county]* [state]
# 3       227538  [county]* [state]
# 4       197601   [county] [state]
# ..         ...                ...
# 65        1965  [county]* [state]
# 66        2245  [county]* [state]
# 67         772  [county]* [state]
# 68        5504                NaN
# 69     3215185                NaN
#
# [70 rows x 8 columns]

# %%
#Exploritory Data Analysis - we do not need all the columns provided. We also will remove rows with Unassigned County
# I also set the NaN values to 0 (zero)
#drop the columns we are not using (NewCases, NewDeaths, ActiveCases, Source)
df_fla.drop(['NewCases', 'NewDeaths', 'ActiveCases', 'Source'], axis = 1, inplace=True) 
df_fla.drop(index=0, inplace=True)                           # remove the Florid Total row

indexNames = df_fla[ df_fla['County'] == 'Unassigned'].index  # get rows where county is unassigned 
df_fla.drop(indexNames , inplace=True)                        # drop them

indexNames = df_fla[ df_fla['County'] == 'Total:'].index  # get rows where county is Total
df_fla.drop(indexNames , inplace=True)                         #drop it

df_fla.fillna(0, inplace=True)                                              # fill NaN values with 0
df_fla.reset_index(drop=True, inplace=True)                  # reset the index
df_fla
# Out:
#           County  TotalCases  TotalDeaths  TotalTests
# 0     Miami-Dade       95068       1354.0      535356
# 1        Broward       45010        536.0      343039
# 2     Palm Beach       28267        727.0      227538
# 3   Hillsborough       25432        278.0      197601
# 4         Orange       25254        156.0      225348
# ..           ...         ...          ...         ...
# 62         Dixie         208          4.0        2130
# 63         Union         169          3.0        2959
# 64     Jefferson         156          5.0        1965
# 65      Franklin          82          1.0        2245
# 66     Lafayette          75          0.0         772
#
# [67 rows x 4 columns]

# %%
#copy the datafram to preserve the original and add the Long and Lat columns
df_tmp = df_fla
df_tmp['Latitude'], df_tmp['Longitude'] = [1.1, 1.2]
df_tmp
# Out:
#           County  TotalCases  TotalDeaths  TotalTests  Latitude  Longitude
# 0     Miami-Dade       95068       1354.0      535356       1.1        1.2
# 1        Broward       45010        536.0      343039       1.1        1.2
# 2     Palm Beach       28267        727.0      227538       1.1        1.2
# 3   Hillsborough       25432        278.0      197601       1.1        1.2
# 4         Orange       25254        156.0      225348       1.1        1.2
# ..           ...         ...          ...         ...       ...        ...
# 62         Dixie         208          4.0        2130       1.1        1.2
# 63         Union         169          3.0        2959       1.1        1.2
# 64     Jefferson         156          5.0        1965       1.1        1.2
# 65      Franklin          82          1.0        2245       1.1        1.2
# 66     Lafayette          75          0.0         772       1.1        1.2
#
# [67 rows x 6 columns]

# %%
import geocoder # import geocoder

# loop over the counties
print('Looping over the list of Counties.')
for index, row in df_tmp.iterrows():
    g=geocoder.arcgis('{}, Florida'.format(row.County))              #get each tal, long
    lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]                                     # assign values
    longitude = lat_lng_coords[1]
    df_tmp.at[index, 'Latitude'] = latitude                         # update the dataframe
    df_tmp.at[index, 'Longitude'] = longitude
    print(row.County+'                   ', end='\r')               # Show progress bar
print('                                        ')                   # clear progress bar
print('Complete')
df_tmp.at[4, 'Latitude'] = 28.540786                         # fix coords for Orange county since geo picks orange NY
df_tmp.at[4, 'Longitude'] = -81.370648
df_tmp
# Out:
# Looping over the list of Counties.
#
# Complete
#           County  TotalCases  TotalDeaths  TotalTests   Latitude  Longitude
# 0     Miami-Dade       95068       1354.0      535356  25.614182 -80.567908
# 1        Broward       45010        536.0      343039  26.152246 -80.487053
# 2     Palm Beach       28267        727.0      227538  26.703060 -80.036610
# 3   Hillsborough       25432        278.0      197601  27.930230 -82.307857
# 4         Orange       25254        156.0      225348  28.540786 -81.370648
# ..           ...         ...          ...         ...        ...        ...
# 62         Dixie         208          4.0        2130  27.938700 -82.486100
# 63         Union         169          3.0        2959  30.803800 -86.042160
# 64     Jefferson         156          5.0        1965  30.437669 -83.895184
# 65      Franklin          82          1.0        2245  29.749190 -85.028540
# 66     Lafayette          75          0.0         772  30.427980 -84.216290
#
# [67 rows x 6 columns]

# %%
#trun off the depreciation warnings
import warnings
warnings.filterwarnings('ignore')

# definition of the boundaries in the map
county_geo = 'florida_counties.geojson'
  
# get county name and count of cases
map_data = df_tmp
map_data.sort_values(by='TotalCases', ascending=True)
  
# creation of the choropleth
import folium
map1 = folium.Map(location=[27.6648, -81.5158], zoom_start=7)
map1.choropleth(geo_data = county_geo,
              data = map_data,
              columns = ['County', 'TotalCases'],
              key_on = 'feature.properties.county',
              fill_color = 'BuPu', 
              fill_opacity = 0.4, 
              line_opacity = 0.2,
              legend_name = 'Number of Covid-19 cases by County', 
                bins=3)
               
display(map1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Comment:
# Since the range of case countvary drastically, the heat map is not effect.
# I test the bubble map below which presents a superiour view if the case count by county

# %%
# Plot all counties where total case >= 1000
map2 = folium.Map(location=[27.6648, -81.5158], zoom_start=7)

map_data2 = map_data              #copy df to retain original
map_data2 = map_data2.astype({'TotalCases': 'float'})   # change data type to float for use in the Circle function

# I can add marker one by one on the map
for i in range(0,len(map_data2)):
    if map_data2.iloc[i]['TotalCases'] > 999:
        folium.Circle(
          location=[map_data2.iloc[i]['Latitude'], map_data2.iloc[i]['Longitude']],
          popup=map_data2.iloc[i]['TotalCases'],
          radius=map_data2.iloc[i]['TotalCases'],
          color='crimson',
          fill=True,
          fill_color='crimson',
       ).add_to(map2)

display(map2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get input from user to swelect region of fl to view
from ipywidgets import Layout, Button, Box, FloatText, Textarea, Dropdown, Label, IntSlider

#define widgets
meters = IntSlider(min=0, max=100, step=5)
meters.value=5
area = Dropdown(options=['North Florida', 'Central Florida', 'South Florida'])
venues = Dropdown(options=['Beach', 'Parks', 'Theme Parks'])

#define layout
form_item_layout = Layout(
    display='flex',
    flex_flow='row',
    justify_content='space-between'
)

#create form items
form_items = [
    Box([Label(value='Search Distance: miles'), meters], layout=form_item_layout),
    Box([Label(value='Select Area'),
         area], layout=form_item_layout),
    Box([Label(value='Select Venue'),
         venues], layout=form_item_layout),
]

#create form
form = Box(form_items, layout=Layout(
    display='flex',
    flex_flow='column',
    border='solid 2px',
    align_items='stretch',
    width='50%'
))
form        #display form for user input
# Out:
# Box(children=(Box(children=(Label(value='Search Distance: miles'), IntSlider(value=5, step=5)), layout=Layout(…

# %%
import yaml
import sys, os

with open("c:\Python\Python38\config.yml", "r") as ymlfile:
    cfg = yaml.safe_load(ymlfile)

CLIENT_ID = cfg['client_id']
CLIENT_SECRET = cfg['client_secret']
VERSION = '20180605' # Foursquare API version

#get credentials from config file

# %%
#find chosen venues in the are selected
print(area.value, venues.value)   #verify selected choices

#setup foursquare search values
limit = 100
radius = meters.value * 1609

#setup caegory search values
cat_beach = '4bf58dd8d48988d1e2941735'
cat_theme = '4bf58dd8d48988d182941735'
cat_park = '52e81612bcbc57f1066b7a21'

if venues.value == 'Beach':     # which category was selected
    cat_id = cat_beach
elif venues.value == 'Theme Parks':
    cat_id = cat_theme
else:
    cat_id = cat_park

if area.value == 'Central Florida':     #set coords to Orlando
    area_lat = 28.540786
    area_long = -81.676325
    url = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(cat_id, CLIENT_ID, CLIENT_SECRET, VERSION, area_lat, area_long,  radius, limit)
elif area.value == 'North Florida':     #set coords to Jacksonville
    area_lat = 30.474970
    area_long = -81.370648
    url = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(cat_id, CLIENT_ID, CLIENT_SECRET, VERSION, area_lat, area_long,  radius, limit)
elif area.value == 'South Florida':     #set coords to Miami
    area_lat = 25.801247
    area_long = -80.221564
    url = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(cat_id, CLIENT_ID, CLIENT_SECRET, VERSION, area_lat, area_long,  radius, limit)

else:
    print(area.value)
# Out:
# Central Florida Theme Parks

# %%
results = requests.get(url).json()    # make the Foursquare request
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f19e46a0c154050638f309f'},
#  'response': {'venues': [{'id': '4acb60d2f964a52094c320e3',
#     'name': "Disney's Hollywood Studios",
#     'location': {'address': '351 S Studio Dr',
#      'crossStreet': 'E Buena Vista Dr',
#      'lat': 28.358045447549014,
#      'lng': -81.55914187004456,
#      'labeledLatLngs': [{'label': 'routing',
#        'lat': 28.353703311855732,
#        'lng': -81.55956029891968},
#       {'label': 'display',
#        'lat': 28.358045447549014,
#        'lng': -81.55914187004456}],
#      'distance': 23353,
#      'postalCode': '32830',
#      'cc': 'US',
#      'neighborhood': 'Walt Disney World Resort',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['351 S Studio Dr (E Buena Vista Dr)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b301d74f964a52053f624e3',
#     'name': 'Epcot',
#     'location': {'address': '200 Epcot Center Dr',
#      'crossStreet': 'Walt Disney World Resort',
#      'lat': 28.374694,
#      'lng': -81.549404,
#      'labeledLatLngs': [{'label': 'routing',
#        'lat': 28.380813239259005,
#        'lng': -81.55576765537262},
#       {'label': 'display', 'lat': 28.374694, 'lng': -81.549404}],
#      'distance': 22274,
#      'postalCode': '32821',
#      'cc': 'US',
#      'neighborhood': 'Walt Disney World Resort',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['200 Epcot Center Dr (Walt Disney World Resort)',
#       'Orlando, FL 32821',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b11d311f964a520758523e3',
#     'name': 'Magic Kingdom® Park',
#     'location': {'address': '1180 Seven Seas Dr',
#      'crossStreet': 'Walt Disney World Resort',
#      'lat': 28.416314849684184,
#      'lng': -81.58102880025481,
#      'labeledLatLngs': [{'label': 'routing',
#        'lat': 28.39287127676242,
#        'lng': -81.57080948352814}],
#      'distance': 16701,
#      'postalCode': '32836',
#      'cc': 'US',
#      'neighborhood': 'Walt Disney World Resort',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1180 Seven Seas Dr (Walt Disney World Resort)',
#       'Lake Buena Vista, FL 32836',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b0b1c8bf964a520122d23e3',
#     'name': 'Test Track Presented by Chevrolet',
#     'location': {'address': '1440 Avenue of the Stars',
#      'crossStreet': 'Epcot Future World',
#      'lat': 28.372799,
#      'lng': -81.547224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.372799,
#        'lng': -81.547224}],
#      'distance': 22568,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1440 Avenue of the Stars (Epcot Future World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b3e51fdf964a520339b25e3',
#     'name': "Soarin'",
#     'location': {'address': '1994 Avenue of the Stars',
#      'crossStreet': 'Epcot Future World',
#      'lat': 28.373657992754826,
#      'lng': -81.55200728842891,
#      'distance': 22229,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1994 Avenue of the Stars (Epcot Future World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b09a3d2f964a520d21a23e3',
#     'name': 'Haunted Mansion',
#     'location': {'address': '1180 Seven Seas Dr',
#      'crossStreet': 'Magic Kingdom Liberty Square',
#      'lat': 28.4201897,
#      'lng': -81.5828486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.4201897,
#        'lng': -81.5828486}],
#      'distance': 16244,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1180 Seven Seas Dr (Magic Kingdom Liberty Square)',
#       'Orlando, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '590452d7e1f0aa59113ca5c9',
#     'name': 'Avatar Flight of Passage',
#     'location': {'address': 'Pandora - The World of Avatar',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.3555672,
#      'lng': -81.5922259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.3555672,
#        'lng': -81.5922259}],
#      'distance': 22200,
#      'postalCode': '32830',
#      'cc': 'US',
#      'neighborhood': 'Walt Disney World Resort',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Pandora - The World of Avatar (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b43df91f964a520d5ec25e3',
#     'name': 'Spaceship Earth',
#     'location': {'address': '2060 Avenue of the Stars',
#      'crossStreet': 'Epcot Future World',
#      'lat': 28.375203112607274,
#      'lng': -81.54943657204936,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.375203112607274,
#        'lng': -81.54943657204936}],
#      'distance': 22225,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['2060 Avenue of the Stars (Epcot Future World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b3387f2f964a520631a25e3',
#     'name': 'The Land Pavilion',
#     'location': {'address': '2010 Avenue of the Stars',
#      'crossStreet': 'Epcot Future World',
#      'lat': 28.37391433826054,
#      'lng': -81.55173822644737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.37391433826054,
#        'lng': -81.55173822644737}],
#      'distance': 22220,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['2010 Avenue of the Stars (Epcot Future World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b058693f964a5206e6622e3',
#     'name': "Disney's Animal Kingdom",
#     'location': {'address': '551 Rainforest Rd',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.359719,
#      'lng': -81.591313,
#      'labeledLatLngs': [{'label': 'routing',
#        'lat': 28.348535316626407,
#        'lng': -81.58969759941101},
#       {'label': 'display', 'lat': 28.359719, 'lng': -81.591313}],
#      'distance': 21806,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['551 Rainforest Rd (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b741f98f964a520f2c82de3',
#     'name': 'World Showcase',
#     'location': {'address': 'Epcot',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.371928562277713,
#      'lng': -81.54935575073337,
#      'distance': 22533,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Epcot (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b0ad282f964a520732823e3',
#     'name': 'Future World',
#     'location': {'address': 'Epcot',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.37401404513753,
#      'lng': -81.54945752865652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.37401404513753,
#        'lng': -81.54945752865652}],
#      'distance': 22334,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Epcot (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '58ba5402109dfe053dd30fa2',
#     'name': 'Pandora - The World of Avatar',
#     'location': {'address': '2901 Osceola Pkwy Ste A',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.3557365,
#      'lng': -81.5921957,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.3557365,
#        'lng': -81.5921957}],
#      'distance': 22184,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['2901 Osceola Pkwy Ste A (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '5b02e5e8e65d0c002c6d4a31',
#     'name': 'Toy Story Land',
#     'location': {'address': '351 S Studio Dr, Hollywood Studios',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.355984054182596,
#      'lng': -81.56132519245148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.355984054182596,
#        'lng': -81.56132519245148}],
#      'distance': 23449,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['351 S Studio Dr, Hollywood Studios (Walt Disney World)',
#       'Orlando, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '5de80fed6b567c000848d556',
#     'name': 'Star Wars: Rise of the Resistance',
#     'location': {'address': '384 Cypress Dr',
#      'crossStreet': "Star Wars: Galaxy's Edge",
#      'lat': 28.354131,
#      'lng': -81.56013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.354131,
#        'lng': -81.56013}],
#      'distance': 23687,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["384 Cypress Dr (Star Wars: Galaxy's Edge)",
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4ad62c90f964a5208c0521e3',
#     'name': 'Universal Studios Florida',
#     'location': {'address': '6000 Universal Blvd',
#      'lat': 28.477820576261742,
#      'lng': -81.46954536437988,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.477820576261742,
#        'lng': -81.46954536437988}],
#      'distance': 21407,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6000 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b0d65bdf964a520794723e3',
#     'name': 'Africa',
#     'location': {'address': 'Animal Kindgom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.35864789597753,
#      'lng': -81.59189781875655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.35864789597753,
#        'lng': -81.59189781875655}],
#      'distance': 21894,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Animal Kindgom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '53875e26498ec3fd59094bf4',
#     'name': 'The Wizarding World Of Harry Potter - Diagon Alley',
#     'location': {'address': 'Diagon Alley',
#      'crossStreet': 'Universal Studios Florida',
#      'lat': 28.479607704413244,
#      'lng': -81.4697171016355,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.479607704413244,
#        'lng': -81.4697171016355}],
#      'distance': 21326,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Diagon Alley (Universal Studios Florida)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4bd489246f649521008b6dec',
#     'name': 'Echo Lake',
#     'location': {'address': "Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.357168958669295,
#      'lng': -81.55924245715141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.357168958669295,
#        'lng': -81.55924245715141}],
#      'distance': 23433,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Disney's Hollywood Studios (Walt Disney World)",
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b097f1af964a520441823e3',
#     'name': 'Tomorrowland',
#     'location': {'address': 'Magic Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.418654840117053,
#      'lng': -81.57942779560716,
#      'distance': 16574,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Magic Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b09b155f964a520cf1b23e3',
#     'name': 'Frontierland',
#     'location': {'address': 'Magic Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.419297233349162,
#      'lng': -81.58456358873207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.419297233349162,
#        'lng': -81.58456358873207}],
#      'distance': 16233,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Magic Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b520c1df964a520e96327e3',
#     'name': 'The Wizarding World Of Harry Potter - Hogsmeade',
#     'location': {'address': 'Islands of Adventure',
#      'crossStreet': 'at Universal Orlando Resort',
#      'lat': 28.472886208758386,
#      'lng': -81.47282264165408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.472886208758386,
#        'lng': -81.47282264165408}],
#      'distance': 21293,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Islands of Adventure (at Universal Orlando Resort)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b5f453ff964a52020b129e3',
#     'name': 'Asia',
#     'location': {'address': 'Animal Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.358540610546264,
#      'lng': -81.58907614092922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.358540610546264,
#        'lng': -81.58907614092922}],
#      'distance': 22011,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Animal Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4bc45a54461576b052bf7f32',
#     'name': 'DinoLand U.S.A.',
#     'location': {'address': 'Animal Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.356401892469716,
#      'lng': -81.5883854849699,
#      'distance': 22257,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Animal Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4d6b1364994f224b348210eb',
#     'name': 'Universal Orlando Resort',
#     'location': {'address': '6000 Universal Blvd',
#      'lat': 28.471256628967602,
#      'lng': -81.467764377594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.471256628967602,
#        'lng': -81.467764377594}],
#      'distance': 21820,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6000 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '5a08956ab3d8e22ec61e361e',
#     'name': "Star Wars: Galaxy's Edge",
#     'location': {'address': "Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.35405560565534,
#      'lng': -81.5620493888855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.35405560565534,
#        'lng': -81.5620493888855}],
#      'distance': 23604,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Disney's Hollywood Studios (Walt Disney World)",
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4ae489a5f964a5206c9b21e3',
#     'name': 'Pirates of the Caribbean',
#     'location': {'address': '4875 Caribbean Way',
#      'crossStreet': 'Magic Kingdom Adventureland',
#      'lat': 28.418080918852077,
#      'lng': -81.58421621114246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.418080918852077,
#        'lng': -81.58421621114246}],
#      'distance': 16364,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['4875 Caribbean Way (Magic Kingdom Adventureland)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b099894f964a520141a23e3',
#     'name': 'Space Mountain',
#     'location': {'address': '4950 N World Dr',
#      'crossStreet': 'Magic Kingdom Tomorrowland',
#      'lat': 28.418797272316496,
#      'lng': -81.578303638664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.418797272316496,
#        'lng': -81.578303638664}],
#      'distance': 16625,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['4950 N World Dr (Magic Kingdom Tomorrowland)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b1d7e83f964a520451124e3',
#     'name': 'Star Tours (Star Tours – The Adventures Continue)',
#     'location': {'address': '355 Cypress Dr',
#      'crossStreet': "Disney's Hollywood Studios Echo Lake",
#      'lat': 28.355594377409073,
#      'lng': -81.55876043576346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.355594377409073,
#        'lng': -81.55876043576346}],
#      'distance': 23609,
#      'postalCode': '32821',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["355 Cypress Dr (Disney's Hollywood Studios Echo Lake)",
#       'Lake Buena Vista, FL 32821',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b59beb8f964a520c99528e3',
#     'name': "Universal's Islands of Adventure",
#     'location': {'address': '6000 Universal Blvd',
#      'lat': 28.472256336923486,
#      'lng': -81.47132635116577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.472256336923486,
#        'lng': -81.47132635116577}],
#      'distance': 21455,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6000 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533190',
#     'hasPerk': False},
#    {'id': '4b901bfff964a5202e7633e3',
#     'name': 'Splash Mountain',
#     'location': {'address': '4955 Caribbean Way',
#      'crossStreet': 'Magic Kingdom Frontierland',
#      'lat': 28.419610828311058,
#      'lng': -81.58525574006032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.419610828311058,
#        'lng': -81.58525574006032}],
#      'distance': 16166,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['4955 Caribbean Way (Magic Kingdom Frontierland)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4ae466f4f964a520589a21e3',
#     'name': 'Main Street, U.S.A.',
#     'location': {'address': 'Magic Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.416864187623105,
#      'lng': -81.58126824214334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.416864187623105,
#        'lng': -81.58126824214334}],
#      'distance': 16637,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Magic Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4f218d0be4b0a021584f2910',
#     'name': 'Main Entrance Hollywood Studios',
#     'location': {'address': "Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.358302797283727,
#      'lng': -81.5587723025268,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.358302797283727,
#        'lng': -81.5587723025268}],
#      'distance': 23345,
#      'postalCode': '32830',
#      'cc': 'US',
#      'neighborhood': 'Walt Disney World Resort',
#      'city': 'Bay Lake',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Disney's Hollywood Studios (Walt Disney World)",
#       'Bay Lake, FL 32830',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b57bc1cf964a5207c3e28e3',
#     'name': "Rock 'n' Roller Coaster Starring Aerosmith (Rock 'N' Roller Coaster Starring Aerosmith)",
#     'location': {'address': "Sunset Blvd, Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.359672854464165,
#      'lng': -81.5606774400675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.359672854464165,
#        'lng': -81.5606774400675}],
#      'distance': 23121,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Sunset Blvd, Disney's Hollywood Studios (Walt Disney World)",
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '5d38e5b523f68a0008e6086c',
#     'name': 'Millennium Falcon: Smugglers Run',
#     'location': {'address': "Star Wars: Galaxy's Edge, Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.353737,
#      'lng': -81.56178,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.353737,
#        'lng': -81.56178}],
#      'distance': 23648,
#      'postalCode': '34747',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Star Wars: Galaxy's Edge, Hollywood Studios (Walt Disney World)",
#       'Lake Buena Vista, FL 34747',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b097b43f964a520f81723e3',
#     'name': 'Adventureland',
#     'location': {'address': 'Magic Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.41844379773945,
#      'lng': -81.58326158232673,
#      'distance': 16382,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Magic Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b058692f964a520536622e3',
#     'name': 'SeaWorld Orlando',
#     'location': {'address': '7007 Sea World Dr',
#      'lat': 28.41161531391359,
#      'lng': -81.46226913117356,
#      'distance': 25406,
#      'postalCode': '32821',
#      'cc': 'US',
#      'neighborhood': 'SeaWorl',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['7007 Sea World Dr',
#       'Orlando, FL 32821',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '392783305'},
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b5218a6f964a5207d6727e3',
#     'name': 'Port Of Entry',
#     'location': {'address': 'Islands of Adventure',
#      'crossStreet': 'at Universal Orlando Resort',
#      'lat': 28.472135137409715,
#      'lng': -81.46863672399505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.472135137409715,
#        'lng': -81.46863672399505}],
#      'distance': 21706,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Islands of Adventure (at Universal Orlando Resort)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b9425fbf964a520406b34e3',
#     'name': 'Hollywood Boulevard',
#     'location': {'address': "Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.357987517165295,
#      'lng': -81.559224064539,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.357987517165295,
#        'lng': -81.559224064539}],
#      'distance': 23354,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Disney's Hollywood Studios (Walt Disney World)",
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b09b179f964a520d31b23e3',
#     'name': 'Liberty Square',
#     'location': {'address': 'Magic Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.41925520875911,
#      'lng': -81.58235514017058,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.41925520875911,
#        'lng': -81.58235514017058}],
#      'distance': 16357,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Magic Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4c9f82f546978cfa8498ab7f',
#     'name': 'New York',
#     'location': {'address': 'Universal Studios Florida',
#      'crossStreet': 'Universal Orlando Resort',
#      'lat': 28.47608531951094,
#      'lng': -81.46954536437988,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47608531951094,
#        'lng': -81.46954536437988}],
#      'distance': 21471,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Universal Studios Florida (Universal Orlando Resort)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4bc7bd166501c9b6f0193f29',
#     'name': 'Sunset Boulevard',
#     'location': {'address': "Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.358273047028007,
#      'lng': -81.5598976356072,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.358273047028007,
#        'lng': -81.5598976356072}],
#      'distance': 23294,
#      'postalCode': '32830',
#      'cc': 'US',
#      'neighborhood': 'Walt Disney World Resort',
#      'city': 'Bay Lake',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Disney's Hollywood Studios (Walt Disney World)",
#       'Bay Lake, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4b098951f964a520041923e3',
#     'name': 'Fantasyland',
#     'location': {'address': 'Magic Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.4203184985193,
#      'lng': -81.58040232425351,
#      'distance': 16368,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Magic Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4ba7bdfdf964a52022af39e3',
#     'name': 'The Lost Continent',
#     'location': {'address': 'Islands of Adventure',
#      'crossStreet': 'at Universal Orlando Resort',
#      'lat': 28.473194536499598,
#      'lng': -81.47197129279124,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.473194536499598,
#        'lng': -81.47197129279124}],
#      'distance': 21359,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Islands of Adventure (at Universal Orlando Resort)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4be3094ed27a20a1280f915b',
#     'name': 'Toon Lagoon',
#     'location': {'address': 'Islands of Adventure',
#      'crossStreet': 'at Universal Orlando Resort',
#      'lat': 28.47011148054183,
#      'lng': -81.471509359025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47011148054183,
#        'lng': -81.471509359025}],
#      'distance': 21525,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Islands of Adventure (at Universal Orlando Resort)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '5c86aafc5bc27d0025bd8af8',
#     'name': 'Hagrid’s Magical Creatures Motorbike Adventure',
#     'location': {'lat': 28.472957475953613,
#      'lng': -81.47429336144849,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.472957475953613,
#        'lng': -81.47429336144849}],
#      'distance': 21156,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Orlando, FL 32819', 'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '50b7d9dee4b08ce3c6c760a1',
#     'name': 'Discovery Island Area',
#     'location': {'address': 'Animal Kingdom',
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.35723090800767,
#      'lng': -81.58961529453879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.35723090800767,
#        'lng': -81.58961529453879}],
#      'distance': 22125,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Animal Kingdom (Walt Disney World)',
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4cbc65e43481199cc7af6c3f',
#     'name': 'Production Central',
#     'location': {'address': 'Universal Studios Florida',
#      'crossStreet': 'Universal Orlando Resort',
#      'lat': 28.475444021758335,
#      'lng': -81.46806478500366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.475444021758335,
#        'lng': -81.46806478500366}],
#      'distance': 21631,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Universal Studios Florida (Universal Orlando Resort)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d182941735',
#       'name': 'Theme Park',
#       'pluralName': 'Theme Parks',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '5b8c662a2c2d180034d9c00a',
#     'name': "Mickey And Minnie's Runaway Railway",
#     'location': {'address': "Hollywood Boulevard, Disney's Hollywood Studios",
#      'crossStreet': 'Walt Disney World',
#      'lat': 28.356942,
#      'lng': -81.560462,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.356942,
#        'lng': -81.560462}],
#      'distance': 23397,
#      'postalCode': '32830',
#      'cc': 'US',
#      'city': 'Lake Buena Vista',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ["Hollywood Boulevard, Disney's Hollywood Studios (Walt Disney World)",
#       'Lake Buena Vista, FL 32830',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False},
#    {'id': '4cbc667c3481199ca1b06c3f',
#     'name': 'World Expo',
#     'location': {'address': 'Universal Studios Florida',
#      'crossStreet': 'Universal Orlando Resort',
#      'lat': 28.480310242675063,
#      'lng': -81.4685583114624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.480310242675063,
#        'lng': -81.4685583114624}],
#      'distance': 21409,
#      'postalCode': '32821',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Universal Studios Florida (Universal Orlando Resort)',
#       'Orlando, FL 32821',
#       'United States']},
#     'categories': [{'id': '5109983191d435c0d71c2bb1',
#       'name': 'Theme Park Ride / Attraction',
#       'pluralName': 'Theme Park Rides/Attractions',
#       'shortName': 'Theme Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595533191',
#     'hasPerk': False}],
#   'confident': False}}

# %%
from pandas.io.json import json_normalize

venues = results['response']['venues']   #get venues fron json
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['name', 'location.lat', 'location.lng', 'id']
nearby_venues = nearby_venues.loc[:, filtered_columns]

#set lat & long to float
nearbu_venues =  nearby_venues.astype({'location.lat': 'float'})   # change data type to float for use coords
nearbu_venues =  nearby_venues.astype({'location.lng': 'float'})
nearby_venues.head()
# Out:
#                                 name  location.lat  location.lng  \
# 0         Disney's Hollywood Studios     28.358045    -81.559142
# 1                              Epcot     28.374694    -81.549404
# 2                Magic Kingdom® Park     28.416315    -81.581029
# 3  Test Track Presented by Chevrolet     28.372799    -81.547224
# 4                            Soarin'     28.373658    -81.552007
#
#                          id
# 0  4acb60d2f964a52094c320e3
# 1  4b301d74f964a52053f624e3
# 2  4b11d311f964a520758523e3
# 3  4b0b1c8bf964a520122d23e3
# 4  4b3e51fdf964a520339b25e3

# %%
#add venue markers to map

for idx, row in nearby_venues.iterrows():
    folium.Marker([row['location.lat'], row['location.lng']], popup=row['name']).add_to(map2)
    
display(map2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# For Beach goers South Jacksonville, Cenral Florida and the entire Gulf Coast look the safest.
# For Theme Parks, Disney looks relatively safe.
# National Parks not in 'Hot' zones would likley be safe however many of them remain closed and must be researched individually.
